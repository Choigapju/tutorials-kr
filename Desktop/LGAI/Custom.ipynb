# %% [markdown]
# # 영업 성공 여부 분류 경진대회

# %% [markdown]
# ## 1. 데이터 확인

# %% [markdown]
# ### 필수 라이브러리

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ### 데이터 셋 읽어오기

# %%
df_train = pd.read_csv("train.csv") # 학습용 데이터
df_test = pd.read_csv("submission.csv") # 테스트 데이터(제출파일의 데이터)

# %%
df_train.head() # 학습용 데이터 살펴보기
# Out:
#    bant_submit          customer_country business_unit  com_reg_ver_win_rate  \
# 0          1.0  /Quezon City/Philippines            AS              0.066667
# 1          1.0        /PH-00/Philippines            AS              0.066667
# 2          1.0           /Kolkata /India            AS              0.088889
# 3          1.0        /Bhubaneswar/India            AS              0.088889
# 4          1.0          /Hyderabad/India            AS              0.088889
#
#    customer_idx          customer_type  enterprise  historical_existing_cnt  \
# 0         32160           End-Customer  Enterprise                      NaN
# 1         23122           End-Customer  Enterprise                     12.0
# 2          1755           End-Customer  Enterprise                    144.0
# 3          4919           End-Customer  Enterprise                      NaN
# 4         17126  Specifier/ Influencer  Enterprise                      NaN
#
#    id_strategic_ver  it_strategic_ver  ...  response_corporate  \
# 0               NaN               NaN  ...               LGEPH
# 1               NaN               NaN  ...               LGEPH
# 2               NaN               NaN  ...               LGEIL
# 3               NaN               NaN  ...               LGEIL
# 4               NaN               NaN  ...               LGEIL
#
#     expected_timeline  ver_cus ver_pro ver_win_rate_x ver_win_ratio_per_bu  \
# 0  less than 3 months        1       0       0.003079             0.026846
# 1  less than 3 months        1       0       0.003079             0.026846
# 2  less than 3 months        1       0       0.003079             0.026846
# 3  less than 3 months        1       0       0.003079             0.026846
# 4  less than 3 months        0       0       0.003079             0.026846
#
#         business_area business_subarea lead_owner is_converted
# 0  corporate / office      Engineering          0         True
# 1  corporate / office      Advertising          1         True
# 2  corporate / office     Construction          2         True
# 3  corporate / office      IT/Software          3         True
# 4  corporate / office              NaN          4         True
#
# [5 rows x 29 columns]

# %%
df_train.isna().sum()
# Out:
# bant_submit                    0
# customer_country             982
# business_unit                  0
# com_reg_ver_win_rate       44731
# customer_idx                   0
# customer_type              43961
# enterprise                     0
# historical_existing_cnt    45543
# id_strategic_ver           55855
# it_strategic_ver           58178
# idit_strategic_ver         54734
# customer_job               18733
# lead_desc_length               0
# inquiry_type                 941
# product_category           19374
# product_subcategory        50064
# product_modelname          50070
# customer_country.1           982
# customer_position              0
# response_corporate             0
# expected_timeline          30863
# ver_cus                        0
# ver_pro                        0
# ver_win_rate_x             40882
# ver_win_ratio_per_bu       43995
# business_area              40882
# business_subarea           53773
# lead_owner                     0
# is_converted                   0
# dtype: int64

# %% [markdown]
# ### 결측치 제거

# %%
df = df_train.copy()

# %%
"""# 결측치를 각 수치형 컬럼의 평균값으로 채우기 (for 루프 사용)
numeric_columns = df_train.select_dtypes(include=['number']).columns
for column in numeric_columns:
    df_train[column].fillna(df_train[column].mean(), inplace=True)"""
# Out:
# "# 결측치를 각 수치형 컬럼의 평균값으로 채우기 (for 루프 사용)\nnumeric_columns = df_train.select_dtypes(include=['number']).columns\nfor column in numeric_columns:\n    df_train[column].fillna(df_train[column].mean(), inplace=True)"

# %%
#'historical_existing_cnt', 'id_strategic_ver', 'it_strategic_ver', 'idit_strategic_ver' 결측치 0 변환
columns_to_replace = ['historical_existing_cnt', 'id_strategic_ver', 'it_strategic_ver', 'idit_strategic_ver']
df[columns_to_replace] = df[columns_to_replace].fillna(0)

# %%
# 0처리 or 중앙값 적용. 현재 0적용
columns_to_replace = ['ver_win_rate_x', 'ver_win_ratio_per_bu']
df[columns_to_replace] = df[columns_to_replace].fillna(0)

# %%
"""# 결측치를 각 범주형 컬럼의 최빈값으로 채우기 (for 루프 사용)
categorical_columns = df_train.select_dtypes(include=['object']).columns
for column in categorical_columns:
    df_train[column].fillna(df_train[column].mode()[0], inplace=True)"""
# Out:
# "# 결측치를 각 범주형 컬럼의 최빈값으로 채우기 (for 루프 사용)\ncategorical_columns = df_train.select_dtypes(include=['object']).columns\nfor column in categorical_columns:\n    df_train[column].fillna(df_train[column].mode()[0], inplace=True)"

# %%
# 이상치가 44731개라 중앙값으로 결측치 대체
median_value = df['com_reg_ver_win_rate'].median()
print(median_value)
df['com_reg_ver_win_rate'] = df['com_reg_ver_win_rate'].fillna(median_value)
# Out:
# 0.0491803278688524

# %%
# 지정된 컬럼들에 대해서만 최빈값으로 NaN을 치환합니다.
columns_to_replace_mode = [
    'customer_country', 'customer_type', 'customer_job', 'inquiry_type', 
    'product_category', 'product_subcategory', 'product_modelname', 
    'expected_timeline', 'business_area', 'business_subarea'
]

for column in columns_to_replace_mode:
    # 컬럼별 최빈값을 계산합니다.
    mode_value = df[column].mode()[0]
    
    # NaN 값을 최빈값으로 치환합니다.
    df[column] = df[column].fillna(mode_value)

# %%
df['com_reg_ver_win_rate']
# Out:
# 0        0.066667
# 1        0.066667
# 2        0.088889
# 3        0.088889
# 4        0.088889
#            ...
# 59294    0.049180
# 59295    0.040000
# 59296    0.040000
# 59297    0.040000
# 59298    0.049180
# Name: com_reg_ver_win_rate, Length: 59299, dtype: float64

# %%
# customer_country.1 컬럼에 대해 국가만 남기고 나머지 정보 생략
df['customer_country.1'] = df['customer_country.1'].str.split('/').str[-1].str.strip()

# %%
# 국가명에 공백이 있는경우 해당 공백 제거
df['customer_country.1'] = df['customer_country.1'].str.replace(' ', '')

# %%
df['customer_country.1']
# Out:
# 0        Philippines
# 1        Philippines
# 2              India
# 3              India
# 4              India
#             ...
# 59294         Poland
# 59295       Colombia
# 59296           Peru
# 59297           Peru
# 59298         France
# Name: customer_country.1, Length: 59299, dtype: object

# %%
mode_value = df['customer_country.1'].mode()[0]
df['customer_country.1'] = df['customer_country.1'].fillna(mode_value)

# %%
df.isnull().sum()
# Out:
# bant_submit                0
# customer_country           0
# business_unit              0
# com_reg_ver_win_rate       0
# customer_idx               0
# customer_type              0
# enterprise                 0
# historical_existing_cnt    0
# id_strategic_ver           0
# it_strategic_ver           0
# idit_strategic_ver         0
# customer_job               0
# lead_desc_length           0
# inquiry_type               0
# product_category           0
# product_subcategory        0
# product_modelname          0
# customer_country.1         0
# customer_position          0
# response_corporate         0
# expected_timeline          0
# ver_cus                    0
# ver_pro                    0
# ver_win_rate_x             0
# ver_win_ratio_per_bu       0
# business_area              0
# business_subarea           0
# lead_owner                 0
# is_converted               0
# dtype: int64

# %%
df['lead_desc_length'].value_counts()
# Out:
# lead_desc_length
# 3      10378
# 14      3180
# 2        934
# 10       891
# 4        884
#        ...
# 824        1
# 559        1
# 676        1
# 907        1
# 726        1
# Name: count, Length: 909, dtype: int64

# %%
df['lead_desc_length']
# Out:
# 0         62
# 1         96
# 2         56
# 3         44
# 4         97
#         ...
# 59294    200
# 59295     70
# 59296     34
# 59297    377
# 59298     78
# Name: lead_desc_length, Length: 59299, dtype: int64

# %% [markdown]
# ### 특성 합성곱

# %%
df
# Out:
#        bant_submit          customer_country business_unit  \
# 0             1.00  /Quezon City/Philippines            AS
# 1             1.00        /PH-00/Philippines            AS
# 2             1.00           /Kolkata /India            AS
# 3             1.00        /Bhubaneswar/India            AS
# 4             1.00          /Hyderabad/India            AS
# ...            ...                       ...           ...
# 59294         1.00           /Sląskie/Poland            AS
# 59295         0.75      /Bogotá DC /Colombia            AS
# 59296         0.75               /Pisco/Peru            AS
# 59297         1.00  /santa cruz bolivia/Peru            AS
# 59298         0.75             /paris/France      Solution
#
#        com_reg_ver_win_rate  customer_idx          customer_type  enterprise  \
# 0                  0.066667         32160           End-Customer  Enterprise
# 1                  0.066667         23122           End-Customer  Enterprise
# 2                  0.088889          1755           End-Customer  Enterprise
# 3                  0.088889          4919           End-Customer  Enterprise
# 4                  0.088889         17126  Specifier/ Influencer  Enterprise
# ...                     ...           ...                    ...         ...
# 59294              0.049180         33747           End Customer         SMB
# 59295              0.040000         35420  Specifier/ Influencer  Enterprise
# 59296              0.040000         19249  Specifier/ Influencer  Enterprise
# 59297              0.040000         40327           End-Customer  Enterprise
# 59298              0.049180         30268           End-Customer  Enterprise
#
#        historical_existing_cnt  id_strategic_ver  it_strategic_ver  ...  \
# 0                          0.0               0.0               0.0  ...
# 1                         12.0               0.0               0.0  ...
# 2                        144.0               0.0               0.0  ...
# 3                          0.0               0.0               0.0  ...
# 4                          0.0               0.0               0.0  ...
# ...                        ...               ...               ...  ...
# 59294                      0.0               0.0               0.0  ...
# 59295                      0.0               0.0               0.0  ...
# 59296                      0.0               0.0               0.0  ...
# 59297                      0.0               0.0               0.0  ...
# 59298                      0.0               0.0               0.0  ...
#
#        response_corporate    expected_timeline  ver_cus ver_pro  \
# 0                   LGEPH   less than 3 months        1       0
# 1                   LGEPH   less than 3 months        1       0
# 2                   LGEIL   less than 3 months        1       0
# 3                   LGEIL   less than 3 months        1       0
# 4                   LGEIL   less than 3 months        0       0
# ...                   ...                  ...      ...     ...
# 59294               LGEPL  3 months ~ 6 months        0       0
# 59295               LGECB    9 months ~ 1 year        0       0
# 59296               LGEPR   less than 3 months        0       0
# 59297               LGEPR     more than a year        0       0
# 59298               LGEKR   less than 3 months        0       0
#
#       ver_win_rate_x ver_win_ratio_per_bu       business_area  \
# 0           0.003079             0.026846  corporate / office
# 1           0.003079             0.026846  corporate / office
# 2           0.003079             0.026846  corporate / office
# 3           0.003079             0.026846  corporate / office
# 4           0.003079             0.026846  corporate / office
# ...              ...                  ...                 ...
# 59294       0.000026             0.028777     public facility
# 59295       0.000026             0.028777     public facility
# 59296       0.000026             0.028777     public facility
# 59297       0.000026             0.028777     public facility
# 59298       0.000026             0.000000     public facility
#
#       business_subarea lead_owner is_converted
# 0          Engineering          0         True
# 1          Advertising          1         True
# 2         Construction          2         True
# 3          IT/Software          3         True
# 4               Others          4         True
# ...                ...        ...          ...
# 59294           Others        694        False
# 59295           Others         39        False
# 59296           Others        125        False
# 59297           Others        134        False
# 59298           Others        441        False
#
# [59299 rows x 29 columns]

# %% [markdown]
# ### 레이블 인코딩

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# 모든 컬럼에 대해 레이블 인코딩 진행
for column in df.columns:
    df[column] = le.fit_transform(df[column])

# %%
df.head()
# Out:
#    bant_submit  customer_country  business_unit  com_reg_ver_win_rate  \
# 0            4              7546              0                    40
# 1            4              6887              0                    40
# 2            4              5037              0                    52
# 3            4              1943              0                    52
# 4            4              4307              0                    52
#
#    customer_idx  customer_type  enterprise  historical_existing_cnt  \
# 0         23743             10           0                        0
# 1         17000             10           0                       12
# 2          1282             10           0                      107
# 3          3571             10           0                        0
# 4         12474             29           0                        0
#
#    id_strategic_ver  it_strategic_ver  ...  response_corporate  \
# 0                 0                 0  ...                  33
# 1                 0                 0  ...                  33
# 2                 0                 0  ...                  21
# 3                 0                 0  ...                  21
# 4                 0                 0  ...                  21
#
#    expected_timeline  ver_cus  ver_pro  ver_win_rate_x  ver_win_ratio_per_bu  \
# 0                246        1        0              12                     5
# 1                246        1        0              12                     5
# 2                246        1        0              12                     5
# 3                246        1        0              12                     5
# 4                246        0        0              12                     5
#
#    business_area  business_subarea  lead_owner  is_converted
# 0              0                28           0             1
# 1              0                 0           1             1
# 2              0                17           2             1
# 3              0                44           3             1
# 4              0                62           4             1
#
# [5 rows x 29 columns]

# %% [markdown]
# 학습 데이터와 제출 데이터 분리

# %%
for col in df.columns:  
    df_train[col] = df.iloc[: len(df_train)][col]
    df_test[col] = df.iloc[len(df_train) :][col]

# %% [markdown]
# ### 학습, 검증 데이터 분리

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df_train.drop("is_converted", axis=1),
    df_train["is_converted"],
    test_size=0.2,
    shuffle=True,
    random_state=400,
)

# %% [markdown]
# ### DecisionTreeClassifer

# %%
"""from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

# DecisionTreeClassifier의 주요 하이퍼파라미터들을 설정
param_grid = {
    'max_depth': [10, 20, 30, 40],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'criterion': ['gini', 'entropy']
}

# DecisionTreeClassifier 모델 생성
dtc = DecisionTreeClassifier()

# GridSearchCV를 이용하여 하이퍼파라미터 튜닝
grid_search = GridSearchCV(estimator=dtc, param_grid=param_grid, cv=5, scoring='f1')
grid_search.fit(X_train, y_train)

# 최적의 하이퍼파라미터 출력
print('Best parameters:', grid_search.best_params_)

# 최적의 하이퍼파라미터를 가진 모델을 사용하여 예측
y_pred = grid_search.predict(X_test)"""
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 17
#      15 # GridSearchCV를 이용하여 하이퍼파라미터 튜닝
#      16 grid_search = GridSearchCV(estimator=dtc, param_grid=param_grid, cv=5, scoring='f1')
# ---> 17 grid_search.fit(X_train, y_train)
#      19 # 최적의 하이퍼파라미터 출력
#      20 print('Best parameters:', grid_search.best_params_)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/model_selection/_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File ~/.local/lib/python3.10/site-packages/sklearn/model_selection/_search.py:1388, in GridSearchCV._run_search(self, evaluate_candidates)
#    1386 def _run_search(self, evaluate_candidates):
#    1387     """Search all candidates in param_grid"""
# -> 1388     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/.local/lib/python3.10/site-packages/sklearn/model_selection/_search.py:821, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     813 if self.verbose > 0:
#     814     print(
#     815         "Fitting {0} folds for each of {1} candidates,"
#     816         " totalling {2} fits".format(
#     817             n_splits, n_candidates, n_candidates * n_splits
#     818         )
#     819     )
# --> 821 out = parallel(
#     822     delayed(_fit_and_score)(
#     823         clone(base_estimator),
#     824         X,
#     825         y,
#     826         train=train,
#     827         test=test,
#     828         parameters=parameters,
#     829         split_progress=(split_idx, n_splits),
#     830         candidate_progress=(cand_idx, n_candidates),
#     831         **fit_and_score_kwargs,
#     832     )
#     833     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     834         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     835     )
#     836 )
#     838 if len(out) < 1:
#     839     raise ValueError(
#     840         "No fits were performed. "
#     841         "Was the CV iterator empty? "
#     842         "Were there no candidates?"
#     843     )
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~/.local/lib/python3.10/site-packages/joblib/parallel.py:1863, in Parallel.__call__(self, iterable)
#    1861     output = self._get_sequential_output(iterable)
#    1862     next(output)
# -> 1863     return output if self.return_generator else list(output)
#    1865 # Let's create an ID that uniquely identifies the current call. If the
#    1866 # call is interrupted early and that the same instance is immediately
#    1867 # re-used, this id will be used to prevent workers that were
#    1868 # concurrently finalizing a task from the previous call to run the
#    1869 # callback.
#    1870 with self._lock:
#
# File ~/.local/lib/python3.10/site-packages/joblib/parallel.py:1792, in Parallel._get_sequential_output(self, iterable)
#    1790 self.n_dispatched_batches += 1
#    1791 self.n_dispatched_tasks += 1
# -> 1792 res = func(*args, **kwargs)
#    1793 self.n_completed_tasks += 1
#    1794 self.print_progress()
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684         estimator.fit(X_train, **fit_params)
#     685     else:
# --> 686         estimator.fit(X_train, y_train, **fit_params)
#     688 except Exception:
#     689     # Note fit time as time until error
#     690     fit_time = time.time() - start_time
#
# File ~/.local/lib/python3.10/site-packages/sklearn/tree/_classes.py:889, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     859 def fit(self, X, y, sample_weight=None, check_input=True):
#     860     """Build a decision tree classifier from the training set (X, y).
#     861
#     862     Parameters
#    (...)
#     886         Fitted estimator.
#     887     """
# --> 889     super().fit(
#     890         X,
#     891         y,
#     892         sample_weight=sample_weight,
#     893         check_input=check_input,
#     894     )
#     895     return self
#
# File ~/.local/lib/python3.10/site-packages/sklearn/tree/_classes.py:379, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     368 else:
#     369     builder = BestFirstTreeBuilder(
#     370         splitter,
#     371         min_samples_split,
#    (...)
#     376         self.min_impurity_decrease,
#     377     )
# --> 379 builder.build(self.tree_, X, y, sample_weight)
#     381 if self.n_outputs_ == 1 and is_classifier(self):
#     382     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
"""# 최적의 하이퍼파라미터를 사용하여 모델 생성
best_dtc = DecisionTreeClassifier(criterion='entropy', max_depth=30, 
                                  min_samples_leaf=2, min_samples_split=2)

# 모델 학습
best_dtc.fit(X_train, y_train)"""

# %%
"""from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score


accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
print("정확도: {:.4f}".format(accuracy))
print("정밀도: {:.4f}".format(precision))
print("재현율: {:.4f}".format(recall))
print("F1: {:.4f}".format(f1))"""

# %% [markdown]
# ### RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

rf = RandomForestClassifier()

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df_train.drop("is_converted", axis=1),
    df_train["is_converted"],
    test_size=0.2,
    shuffle=True,
    random_state=400,
)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
rf.score(X_test, y_test)
# Out:
# 0.972849915682968

# %%
f1 = f1_score(y_test, y_test)
f1
# Out:
# 1.0

# %% [markdown]
# ### XGBoost, GridSearchCV

# %%
from xgboost import XGBClassifier

model =XGBClassifier()

# %%
from sklearn.model_selection import GridSearchCV

model_param_grid={
    'n_estimators': [2, 5, 10, 50, 100, 250, 500],
    'max_depth': [2, 4, 6, 8, 10],
    'learning_rate': [0.01, 0.05, 0.1, 0.5, 1.0, 1.5],
    'objective': ['binary:logistic']
}

# %%
model_grid=GridSearchCV(model, param_grid=model_param_grid, scoring="f1_macro", n_jobs=-1, verbose=2)
model_grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 210 candidates, totalling 1050 fits
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, objective=binary:logistic; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, objective=binary:logistic; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=250, objective=binary:logistic; total time=   1.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=250, objective=binary:logistic; total time=   1.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, objective=binary:logistic; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, objective=binary:logistic; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, objective=binary:logistic; total time=   0.7s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, objective=binary:logistic; total time=   0.7s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=250, objective=binary:logistic; total time=   1.5s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, objective=binary:logistic; total time=   2.8s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, objective=binary:logistic; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, objective=binary:logistic; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, objective=binary:logistic; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=250, objective=binary:logistic; total time=   2.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, objective=binary:logistic; total time=   4.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=50, objective=binary:logistic; total time=   0.7s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=50, objective=binary:logistic; total time=   0.7s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=100, objective=binary:logistic; total time=   1.3s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=250, objective=binary:logistic; total time=   3.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=250, objective=binary:logistic; total time=   3.3s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=500, objective=binary:logistic; total time=   5.8s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=50, objective=binary:logistic; total time=   1.1s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=100, objective=binary:logistic; total time=   1.9s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=100, objective=binary:logistic; total time=   1.9s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=250, objective=binary:logistic; total time=   4.9s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=500, objective=binary:logistic; total time=   8.6s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=50, objective=binary:logistic; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=50, objective=binary:logistic; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=50, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=100, objective=binary:logistic; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=100, objective=binary:logistic; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=250, objective=binary:logistic; total time=   1.0s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=500, objective=binary:logistic; total time=   1.9s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=500, objective=binary:logistic; total time=   1.8s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=50, objective=binary:logistic; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=50, objective=binary:logistic; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=100, objective=binary:logistic; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=250, objective=binary:logistic; total time=   1.4s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=500, objective=binary:logistic; total time=   2.5s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=50, objective=binary:logistic; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=100, objective=binary:logistic; total time=   1.0s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=100, objective=binary:logistic; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, objective=binary:logistic; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, objective=binary:logistic; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, objective=binary:logistic; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=250, objective=binary:logistic; total time=   1.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, objective=binary:logistic; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, objective=binary:logistic; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, objective=binary:logistic; total time=   0.7s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=250, objective=binary:logistic; total time=   1.5s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=250, objective=binary:logistic; total time=   1.5s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, objective=binary:logistic; total time=   2.8s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, objective=binary:logistic; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, objective=binary:logistic; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, objective=binary:logistic; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=250, objective=binary:logistic; total time=   2.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, objective=binary:logistic; total time=   4.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=50, objective=binary:logistic; total time=   0.7s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=50, objective=binary:logistic; total time=   0.7s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=100, objective=binary:logistic; total time=   1.3s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=250, objective=binary:logistic; total time=   3.3s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=500, objective=binary:logistic; total time=   6.1s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=500, objective=binary:logistic; total time=   6.2s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=100, objective=binary:logistic; total time=   1.9s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=250, objective=binary:logistic; total time=   4.8s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=500, objective=binary:logistic; total time=   8.8s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=50, objective=binary:logistic; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=50, objective=binary:logistic; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=100, objective=binary:logistic; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=100, objective=binary:logistic; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=250, objective=binary:logistic; total time=   1.1s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=250, objective=binary:logistic; total time=   1.1s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=500, objective=binary:logistic; total time=   1.9s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=50, objective=binary:logistic; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=100, objective=binary:logistic; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=250, objective=binary:logistic; total time=   1.4s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=500, objective=binary:logistic; total time=   2.5s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=500, objective=binary:logistic; total time=   2.5s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=50, objective=binary:logistic; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=100, objective=binary:logistic; total time=   0.9s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=250, objective=binary:logistic; total time=   1.9s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=500, objective=binary:logistic; total time=   3.4s
# [CV] END learning_rate=0.05, max_depth=8, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=8, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=8, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, objective=binary:logistic; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, objective=binary:logistic; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, objective=binary:logistic; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=250, objective=binary:logistic; total time=   1.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, objective=binary:logistic; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, objective=binary:logistic; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, objective=binary:logistic; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, objective=binary:logistic; total time=   0.7s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=250, objective=binary:logistic; total time=   1.5s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, objective=binary:logistic; total time=   2.8s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, objective=binary:logistic; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=50, objective=binary:logistic; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, objective=binary:logistic; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=250, objective=binary:logistic; total time=   2.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=250, objective=binary:logistic; total time=   2.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, objective=binary:logistic; total time=   4.0s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=50, objective=binary:logistic; total time=   0.7s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=100, objective=binary:logistic; total time=   1.3s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=100, objective=binary:logistic; total time=   1.3s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=250, objective=binary:logistic; total time=   3.4s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=500, objective=binary:logistic; total time=   6.1s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=5, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=5, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=50, objective=binary:logistic; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=50, objective=binary:logistic; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=100, objective=binary:logistic; total time=   1.8s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=250, objective=binary:logistic; total time=   4.8s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=250, objective=binary:logistic; total time=   4.9s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=500, objective=binary:logistic; total time=   8.3s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=100, objective=binary:logistic; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=250, objective=binary:logistic; total time=   1.0s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=250, objective=binary:logistic; total time=   1.0s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=500, objective=binary:logistic; total time=   1.9s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=50, objective=binary:logistic; total time=   0.4s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=100, objective=binary:logistic; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=100, objective=binary:logistic; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=250, objective=binary:logistic; total time=   1.4s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=500, objective=binary:logistic; total time=   2.5s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=50, objective=binary:logistic; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=100, objective=binary:logistic; total time=   0.9s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=250, objective=binary:logistic; total time=   1.8s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=250, objective=binary:logistic; total time=   1.8s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=500, objective=binary:logistic; total time=   3.3s
# [CV] END learning_rate=0.05, max_depth=8, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=8, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, objective=binary:logistic; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, objective=binary:logistic; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=250, objective=binary:logistic; total time=   1.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, objective=binary:logistic; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=500, objective=binary:logistic; total time=   1.9s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=50, objective=binary:logistic; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, objective=binary:logistic; total time=   0.7s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=250, objective=binary:logistic; total time=   1.5s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, objective=binary:logistic; total time=   2.8s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, objective=binary:logistic; total time=   2.8s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, objective=binary:logistic; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=250, objective=binary:logistic; total time=   2.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, objective=binary:logistic; total time=   4.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, objective=binary:logistic; total time=   4.0s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=100, objective=binary:logistic; total time=   1.3s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=250, objective=binary:logistic; total time=   3.3s
# [CV] END learning_rate=0.01, max_depth=8, n_estimators=500, objective=binary:logistic; total time=   6.1s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=5, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=5, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=50, objective=binary:logistic; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=50, objective=binary:logistic; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=100, objective=binary:logistic; total time=   1.9s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=250, objective=binary:logistic; total time=   4.7s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=500, objective=binary:logistic; total time=   8.5s
# [CV] END learning_rate=0.01, max_depth=10, n_estimators=500, objective=binary:logistic; total time=   8.5s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=500, objective=binary:logistic; total time=   1.9s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=50, objective=binary:logistic; total time=   0.5s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=100, objective=binary:logistic; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=250, objective=binary:logistic; total time=   1.4s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=250, objective=binary:logistic; total time=   1.4s
# [CV] END learning_rate=0.05, max_depth=4, n_estimators=500, objective=binary:logistic; total time=   2.5s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=50, objective=binary:logistic; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=50, objective=binary:logistic; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=100, objective=binary:logistic; total time=   1.0s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=250, objective=binary:logistic; total time=   1.9s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=500, objective=binary:logistic; total time=   3.3s
# [CV] END learning_rate=0.05, max_depth=6, n_estimators=500, objective=binary:logistic; total time=   3.3s
# [CV] END learning_rate=0.05, max_depth=8, n_estimators=100, objective=binary:logistic; total time=   1.4s
# [CV] END learning_rate=0.05, max_depth=8, n_estimators=250, objective=binary:logistic; total time=   2.6s
# [CV] END learning_rate=0.05, max_depth=8, n_estimators=250, objective=binary:logistic; total time=   2.6s
# [CV] END learning_rate=0.05, max_depth=8, n_estimators=500, objective=binary:logistic; total time=   4.5s
# [CV] END learning_rate=0.05, max_depth=10, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=10, n_estimators=50, objective=binary:logistic; total time=   1.1s
# [CV] END learning_rate=0.05, max_depth=10, n_estimators=100, objective=binary:logistic; total time=   1.8s
# [CV] END learning_rate=0.05, max_depth=10, n_estimators=100, objective=binary:logistic; total time=   1.9s
# [CV] END learning_rate=0.05, max_depth=10, n_estimators=250, objective=binary:logistic; total time=   3.4s
# [CV] END learning_rate=0.05, max_depth=10, n_estimators=500, objective=binary:logistic; total time=   5.8s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, objective=binary:logistic; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, objective=binary:logistic; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, objective=binary:logistic; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=250, objective=binary:logistic; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=250, objective=binary:logistic; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=500, objective=binary:logistic; total time=   1.9s
# [CV] END learning_rate=0.1, max_depth=4, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=4, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=8, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=8, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=8, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=8, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=8, n_estimators=50, objective=binary:logistic; total time=   0.8s
# [CV] END learning_rate=0.05, max_depth=8, n_estimators=50, objective=binary:logistic; total time=   0.8s
# [CV] END learning_rate=0.05, max_depth=8, n_estimators=100, objective=binary:logistic; total time=   1.3s
# [CV] END learning_rate=0.05, max_depth=8, n_estimators=250, objective=binary:logistic; total time=   2.6s
# [CV] END learning_rate=0.05, max_depth=8, n_estimators=500, objective=binary:logistic; total time=   4.6s
# [CV] END learning_rate=0.05, max_depth=8, n_estimators=500, objective=binary:logistic; total time=   4.6s
# [CV] END learning_rate=0.05, max_depth=10, n_estimators=100, objective=binary:logistic; total time=   1.9s
# [CV] END learning_rate=0.05, max_depth=10, n_estimators=250, objective=binary:logistic; total time=   3.5s
# [CV] END learning_rate=0.05, max_depth=10, n_estimators=500, objective=binary:logistic; total time=   5.9s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, objective=binary:logistic; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, objective=binary:logistic; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, objective=binary:logistic; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=250, objective=binary:logistic; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=500, objective=binary:logistic; total time=   1.8s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=500, objective=binary:logistic; total time=   1.8s
# [CV] END learning_rate=0.1, max_depth=4, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=4, n_estimators=50, objective=binary:logistic; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=4, n_estimators=100, objective=binary:logistic; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=4, n_estimators=250, objective=binary:logistic; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=4, n_estimators=500, objective=binary:logistic; total time=   2.4s
# [CV] END learning_rate=0.1, max_depth=4, n_estimators=500, objective=binary:logistic; total time=   2.4s
# [CV] END learning_rate=0.1, max_depth=6, n_estimators=50, objective=binary:logistic; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=6, n_estimators=100, objective=binary:logistic; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=6, n_estimators=250, objective=binary:logistic; total time=   1.7s
# [CV] END learning_rate=0.1, max_depth=6, n_estimators=500, objective=binary:logistic; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=6, n_estimators=500, objective=binary:logistic; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=8, n_estimators=100, objective=binary:logistic; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=8, n_estimators=250, objective=binary:logistic; total time=   2.3s
# [CV] END learning_rate=0.1, max_depth=8, n_estimators=250, objective=binary:logistic; total time=   2.4s
# [CV] END learning_rate=0.1, max_depth=8, n_estimators=500, objective=binary:logistic; total time=   4.3s
# [CV] END learning_rate=0.1, max_depth=10, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=10, n_estimators=50, objective=binary:logistic; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=10, n_estimators=50, objective=binary:logistic; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=10, n_estimators=100, objective=binary:logistic; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=10, n_estimators=250, objective=binary:logistic; total time=   3.1s
# [CV] END learning_rate=0.1, max_depth=10, n_estimators=500, objective=binary:logistic; total time=   5.1s
# [CV] END learning_rate=0.5, max_depth=2, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=2, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=2, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=2, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=2, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=2, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=2, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=2, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=2, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=2, n_estimators=50, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=2, n_estimators=50, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=2, n_estimators=50, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=2, n_estimators=100, objective=binary:logistic; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=2, n_estimators=250, objective=binary:logistic; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=2, n_estimators=250, objective=binary:logistic; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=2, n_estimators=500, objective=binary:logistic; total time=   1.9s
# [CV] END learning_rate=0.5, max_depth=4, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=4, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=4, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=4, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=4, n_estimators=50, objective=binary:logistic; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=4, n_estimators=50, objective=binary:logistic; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=4, n_estimators=100, objective=binary:logistic; total time=   0.6s
# [CV] END learning_rate=0.5, max_depth=4, n_estimators=250, objective=binary:logistic; total time=   1.3s
# [CV] END learning_rate=0.5, max_depth=4, n_estimators=500, objective=binary:logistic; total time=   2.6s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=8, n_estimators=50, objective=binary:logistic; total time=   0.8s
# [CV] END learning_rate=0.05, max_depth=8, n_estimators=50, objective=binary:logistic; total time=   0.8s
# [CV] END learning_rate=0.05, max_depth=8, n_estimators=100, objective=binary:logistic; total time=   1.5s
# [CV] END learning_rate=0.05, max_depth=8, n_estimators=250, objective=binary:logistic; total time=   2.5s
# [CV] END learning_rate=0.05, max_depth=8, n_estimators=500, objective=binary:logistic; total time=   4.5s
# [CV] END learning_rate=0.05, max_depth=10, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=10, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=10, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=10, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=10, n_estimators=5, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=10, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.05, max_depth=10, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=10, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.05, max_depth=10, n_estimators=50, objective=binary:logistic; total time=   1.1s
# [CV] END learning_rate=0.05, max_depth=10, n_estimators=50, objective=binary:logistic; total time=   1.1s
# [CV] END learning_rate=0.05, max_depth=10, n_estimators=100, objective=binary:logistic; total time=   1.8s
# [CV] END learning_rate=0.05, max_depth=10, n_estimators=250, objective=binary:logistic; total time=   3.4s
# [CV] END learning_rate=0.05, max_depth=10, n_estimators=500, objective=binary:logistic; total time=   5.8s
# [CV] END learning_rate=0.05, max_depth=10, n_estimators=500, objective=binary:logistic; total time=   6.0s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=500, objective=binary:logistic; total time=   1.9s
# [CV] END learning_rate=0.1, max_depth=4, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=4, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=4, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=4, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=4, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=4, n_estimators=50, objective=binary:logistic; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=4, n_estimators=50, objective=binary:logistic; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=4, n_estimators=100, objective=binary:logistic; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=4, n_estimators=250, objective=binary:logistic; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=4, n_estimators=500, objective=binary:logistic; total time=   2.5s
# [CV] END learning_rate=0.1, max_depth=6, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=6, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=6, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=6, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=6, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=6, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=6, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=6, n_estimators=50, objective=binary:logistic; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=6, n_estimators=100, objective=binary:logistic; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=6, n_estimators=100, objective=binary:logistic; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=6, n_estimators=250, objective=binary:logistic; total time=   1.8s
# [CV] END learning_rate=0.1, max_depth=6, n_estimators=500, objective=binary:logistic; total time=   3.3s
# [CV] END learning_rate=0.1, max_depth=8, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=8, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=8, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=8, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=8, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=8, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=8, n_estimators=50, objective=binary:logistic; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=8, n_estimators=50, objective=binary:logistic; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=8, n_estimators=100, objective=binary:logistic; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=8, n_estimators=250, objective=binary:logistic; total time=   2.3s
# [CV] END learning_rate=0.1, max_depth=8, n_estimators=500, objective=binary:logistic; total time=   4.2s
# [CV] END learning_rate=0.1, max_depth=10, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=10, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=10, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=10, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=10, n_estimators=5, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=10, n_estimators=5, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=10, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=10, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.1, max_depth=10, n_estimators=50, objective=binary:logistic; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=10, n_estimators=50, objective=binary:logistic; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=10, n_estimators=100, objective=binary:logistic; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=10, n_estimators=250, objective=binary:logistic; total time=   3.0s
# [CV] END learning_rate=0.1, max_depth=10, n_estimators=500, objective=binary:logistic; total time=   5.0s
# [CV] END learning_rate=0.1, max_depth=10, n_estimators=500, objective=binary:logistic; total time=   5.2s
# [CV] END learning_rate=0.5, max_depth=2, n_estimators=250, objective=binary:logistic; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=2, n_estimators=500, objective=binary:logistic; total time=   1.9s
# [CV] END learning_rate=0.5, max_depth=4, n_estimators=5, objective=binary:logistic; total time=   0.2s
# ...
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=50, objective=binary:logistic; total time=   0.6s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=50, objective=binary:logistic; total time=   0.6s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=100, objective=binary:logistic; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=250, objective=binary:logistic; total time=   2.2s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=250, objective=binary:logistic; total time=   2.2s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=500, objective=binary:logistic; total time=   4.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=50, objective=binary:logistic; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=50, objective=binary:logistic; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=100, objective=binary:logistic; total time=   1.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=250, objective=binary:logistic; total time=   2.5s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=500, objective=binary:logistic; total time=   4.5s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=500, objective=binary:logistic; total time=   4.6s
# [CV] END learning_rate=1.0, max_depth=2, n_estimators=250, objective=binary:logistic; total time=   1.0s
# [CV] END learning_rate=1.0, max_depth=2, n_estimators=500, objective=binary:logistic; total time=   1.9s
# [CV] END learning_rate=1.0, max_depth=4, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=4, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=4, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=4, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=4, n_estimators=50, objective=binary:logistic; total time=   0.4s
# [CV] END learning_rate=1.0, max_depth=4, n_estimators=100, objective=binary:logistic; total time=   0.7s
# [CV] END learning_rate=1.0, max_depth=4, n_estimators=250, objective=binary:logistic; total time=   1.5s
# [CV] END learning_rate=1.0, max_depth=4, n_estimators=250, objective=binary:logistic; total time=   1.4s
# [CV] END learning_rate=1.0, max_depth=4, n_estimators=500, objective=binary:logistic; total time=   2.7s
# [CV] END learning_rate=1.0, max_depth=6, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=6, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=6, n_estimators=50, objective=binary:logistic; total time=   0.5s
# [CV] END learning_rate=1.0, max_depth=6, n_estimators=100, objective=binary:logistic; total time=   0.9s
# [CV] END learning_rate=1.0, max_depth=6, n_estimators=100, objective=binary:logistic; total time=   0.9s
# [CV] END learning_rate=1.0, max_depth=6, n_estimators=250, objective=binary:logistic; total time=   2.0s
# [CV] END learning_rate=1.0, max_depth=6, n_estimators=500, objective=binary:logistic; total time=   3.6s
# [CV] END learning_rate=1.0, max_depth=8, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=8, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=8, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=8, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=8, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=1.0, max_depth=8, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=1.0, max_depth=8, n_estimators=50, objective=binary:logistic; total time=   0.6s
# [CV] END learning_rate=1.0, max_depth=8, n_estimators=50, objective=binary:logistic; total time=   0.6s
# [CV] END learning_rate=1.0, max_depth=8, n_estimators=100, objective=binary:logistic; total time=   1.1s
# [CV] END learning_rate=1.0, max_depth=8, n_estimators=250, objective=binary:logistic; total time=   2.3s
# [CV] END learning_rate=1.0, max_depth=8, n_estimators=500, objective=binary:logistic; total time=   4.1s
# [CV] END learning_rate=1.0, max_depth=8, n_estimators=500, objective=binary:logistic; total time=   4.5s
# [CV] END learning_rate=1.0, max_depth=10, n_estimators=100, objective=binary:logistic; total time=   1.2s
# [CV] END learning_rate=1.0, max_depth=10, n_estimators=250, objective=binary:logistic; total time=   2.4s
# [CV] END learning_rate=1.0, max_depth=10, n_estimators=500, objective=binary:logistic; total time=   4.5s
# [CV] END learning_rate=1.5, max_depth=2, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.5, max_depth=2, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.5, max_depth=2, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.5, max_depth=2, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.5, max_depth=2, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.5, max_depth=2, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.5, max_depth=2, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.5, max_depth=2, n_estimators=50, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=1.5, max_depth=2, n_estimators=100, objective=binary:logistic; total time=   0.5s
# [CV] END learning_rate=1.5, max_depth=2, n_estimators=100, objective=binary:logistic; total time=   0.5s
# [CV] END learning_rate=1.5, max_depth=2, n_estimators=250, objective=binary:logistic; total time=   1.1s
# [CV] END learning_rate=1.5, max_depth=2, n_estimators=250, objective=binary:logistic; total time=   1.7s
# [CV] END learning_rate=1.5, max_depth=2, n_estimators=500, objective=binary:logistic; total time=   1.8s
# [CV] END learning_rate=1.5, max_depth=4, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.5, max_depth=4, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=250, objective=binary:logistic; total time=   1.8s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, objective=binary:logistic; total time=   3.4s
# [CV] END learning_rate=0.5, max_depth=6, n_estimators=500, objective=binary:logistic; total time=   3.3s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=100, objective=binary:logistic; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=250, objective=binary:logistic; total time=   2.2s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=500, objective=binary:logistic; total time=   4.1s
# [CV] END learning_rate=0.5, max_depth=8, n_estimators=500, objective=binary:logistic; total time=   4.1s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=100, objective=binary:logistic; total time=   1.2s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=250, objective=binary:logistic; total time=   2.6s
# [CV] END learning_rate=0.5, max_depth=10, n_estimators=500, objective=binary:logistic; total time=   4.6s
# [CV] END learning_rate=1.0, max_depth=2, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=2, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=2, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=2, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=2, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=2, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=2, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=2, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=2, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=2, n_estimators=50, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=1.0, max_depth=2, n_estimators=50, objective=binary:logistic; total time=   0.4s
# [CV] END learning_rate=1.0, max_depth=2, n_estimators=100, objective=binary:logistic; total time=   0.5s
# [CV] END learning_rate=1.0, max_depth=2, n_estimators=250, objective=binary:logistic; total time=   1.0s
# [CV] END learning_rate=1.0, max_depth=2, n_estimators=250, objective=binary:logistic; total time=   1.0s
# [CV] END learning_rate=1.0, max_depth=2, n_estimators=500, objective=binary:logistic; total time=   1.9s
# [CV] END learning_rate=1.0, max_depth=4, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=4, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=4, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=4, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=4, n_estimators=50, objective=binary:logistic; total time=   0.4s
# [CV] END learning_rate=1.0, max_depth=4, n_estimators=100, objective=binary:logistic; total time=   0.7s
# [CV] END learning_rate=1.0, max_depth=4, n_estimators=100, objective=binary:logistic; total time=   0.6s
# [CV] END learning_rate=1.0, max_depth=4, n_estimators=250, objective=binary:logistic; total time=   1.5s
# [CV] END learning_rate=1.0, max_depth=4, n_estimators=500, objective=binary:logistic; total time=   2.7s
# [CV] END learning_rate=1.0, max_depth=6, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=6, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=6, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=6, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=6, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=6, n_estimators=10, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=6, n_estimators=50, objective=binary:logistic; total time=   0.5s
# [CV] END learning_rate=1.0, max_depth=6, n_estimators=50, objective=binary:logistic; total time=   0.5s
# [CV] END learning_rate=1.0, max_depth=6, n_estimators=100, objective=binary:logistic; total time=   0.9s
# [CV] END learning_rate=1.0, max_depth=6, n_estimators=250, objective=binary:logistic; total time=   1.9s
# [CV] END learning_rate=1.0, max_depth=6, n_estimators=500, objective=binary:logistic; total time=   3.6s
# [CV] END learning_rate=1.0, max_depth=8, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=8, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=8, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=8, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=8, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=8, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=8, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=1.0, max_depth=8, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=1.0, max_depth=8, n_estimators=50, objective=binary:logistic; total time=   0.7s
# [CV] END learning_rate=1.0, max_depth=8, n_estimators=100, objective=binary:logistic; total time=   1.1s
# [CV] END learning_rate=1.0, max_depth=8, n_estimators=100, objective=binary:logistic; total time=   1.1s
# [CV] END learning_rate=1.0, max_depth=8, n_estimators=250, objective=binary:logistic; total time=   2.2s
# [CV] END learning_rate=1.0, max_depth=8, n_estimators=500, objective=binary:logistic; total time=   4.1s
# [CV] END learning_rate=1.0, max_depth=10, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=10, n_estimators=2, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=10, n_estimators=5, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=1.0, max_depth=10, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.0, max_depth=10, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=1.0, max_depth=10, n_estimators=10, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=1.0, max_depth=10, n_estimators=50, objective=binary:logistic; total time=   0.7s
# [CV] END learning_rate=1.0, max_depth=10, n_estimators=50, objective=binary:logistic; total time=   0.7s
# [CV] END learning_rate=1.0, max_depth=10, n_estimators=100, objective=binary:logistic; total time=   1.2s
# [CV] END learning_rate=1.0, max_depth=10, n_estimators=250, objective=binary:logistic; total time=   2.4s
# [CV] END learning_rate=1.0, max_depth=10, n_estimators=250, objective=binary:logistic; total time=   2.5s
# [CV] END learning_rate=1.0, max_depth=10, n_estimators=500, objective=binary:logistic; total time=   4.2s
# [CV] END learning_rate=1.5, max_depth=2, n_estimators=50, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=1.5, max_depth=2, n_estimators=50, objective=binary:logistic; total time=   0.3s
# [CV] END learning_rate=1.5, max_depth=2, n_estimators=100, objective=binary:logistic; total time=   0.6s
# [CV] END learning_rate=1.5, max_depth=2, n_estimators=100, objective=binary:logistic; total time=   0.8s
# [CV] END learning_rate=1.5, max_depth=2, n_estimators=250, objective=binary:logistic; total time=   1.8s
# [CV] END learning_rate=1.5, max_depth=2, n_estimators=500, objective=binary:logistic; total time=   3.7s
# [CV] END learning_rate=1.5, max_depth=4, n_estimators=5, objective=binary:logistic; total time=   0.2s
# [CV] END learning_rate=1.5, max_depth=4, n_estimators=10, objective=binary:logistic; total time=   0.2s
# GridSearchCV(estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_b...
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.05, 0.1, 0.5, 1.0, 1.5],
#                          'max_depth': [2, 4, 6, 8, 10],
#                          'n_estimators': [2, 5, 10, 50, 100, 250, 500],
#                          'objective': ['binary:logistic']},
#              scoring='f1_macro', verbose=2)

# %%
print(model_grid.best_score_)
print(model_grid.best_params_)
# Out:
# 0.9033455697525767
# {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 500, 'objective': 'binary:logistic'}

# %%
xg_model=XGBClassifier(
    n_estimators= 500,
    max_depth=8,
    learning_rate=0.1,
    objective='binary:logistic'
)

# %%
xg_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_predict=xg_model.predict(X_test)
y_predict.sum()/len(y_predict)
# Out:
# 0.0657672849915683

# %%
xg_model.score(X_test, y_test)
# Out:
# 0.9752951096121416

# %%
xg_f1 = f1_score(y_test, y_predict)
xg_f1
# Out:
# 0.8303416328894035

# %% [markdown]
# ### 제출하기

# %% [markdown]
# 테스트 데이터 예측

# %%
# 예측에 필요한 데이터 분리
X_test = df_test.drop(["is_converted", "id"], axis=1)

# %%
x_test = df_test.drop(["is_converted", "id"], axis=1)

# %%
len(x_test)
# Out:
# 5271

# %%
y_predict = xg_model.predict(X_test.fillna(0))
sum(y_predict)
# Out:
# 780

# %% [markdown]
# ### 제출 파일 작성

# %%
# 제출 데이터 읽어오기 (df_test는 전처리된 데이터가 저장됨)
df_sub = pd.read_csv("submission.csv")
df_sub["is_converted"] = y_predict

# 제출 파일 저장
df_sub.to_csv("submission.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 3
#       1 # 제출 데이터 읽어오기 (df_test는 전처리된 데이터가 저장됨)
#       2 df_sub = pd.read_csv("submission.csv")
# ----> 3 df_sub["is_converted"] = y_predict
#       5 # 제출 파일 저장
#       6 df_sub.to_csv("submission.csv", index=False)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:4091, in DataFrame.__setitem__(self, key, value)
#    4088     self._setitem_array([key], value)
#    4089 else:
#    4090     # set column
# -> 4091     self._set_item(key, value)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:4300, in DataFrame._set_item(self, key, value)
#    4290 def _set_item(self, key, value) -> None:
#    4291     """
#    4292     Add series to DataFrame in specified column.
#    4293
#    (...)
#    4298     ensure homogeneity.
#    4299     """
# -> 4300     value, refs = self._sanitize_column(value)
#    4302     if (
#    4303         key in self.columns
#    4304         and value.ndim == 1
#    4305         and not isinstance(value.dtype, ExtensionDtype)
#    4306     ):
#    4307         # broadcast across multiple columns if necessary
#    4308         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:5039, in DataFrame._sanitize_column(self, value)
#    5036     return _reindex_for_setitem(value, self.index)
#    5038 if is_list_like(value):
# -> 5039     com.require_length_match(value, self.index)
#    5040 return sanitize_array(value, self.index, copy=True, allow_2d=True), None
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/common.py:561, in require_length_match(data, index)
#     557 """
#     558 Check the length of data matches the length of the index.
#     559 """
#     560 if len(data) != len(index):
# --> 561     raise ValueError(
#     562         "Length of values "
#     563         f"({len(data)}) "
#     564         "does not match length of index "
#     565         f"({len(index)})"
#     566     )
#
# ValueError: Length of values (11860) does not match length of index (5271)

# %%
# 제출 데이터 읽어오기 (df_test는 전처리된 데이터가 저장됨)
df_sub = pd.read_csv("submission.csv")

# y_predict의 길이를 df_sub의 길이에 맞게 잘라서 사용
y_predict_trimmed = y_predict[:len(df_sub)]
df_sub["is_converted"] = y_predict_trimmed

# 제출 파일 저장
df_sub.to_csv("submission.csv", index=False)
